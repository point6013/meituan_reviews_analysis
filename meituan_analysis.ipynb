# %%
from pyecharts import Bar,Pie
import pandas as pd
import numpy as np
import  matplotlib.pyplot as  plt
import time

# %%
df=pd.read_excel("all_data_meituan.xlsx")

# %%
df.drop('comment',axis=1).head(2)
# Out:
#    anonymous  avgPrice    commentTime   dealEndtime       did   menu  \
# 0      False        73  1525875708515  1.530338e+09  44328533  单人午晚餐
# 1      False        73  1527853291658  1.530338e+09  44328241  2人午晚餐
#
#                                              picUrls  quality  readCnt  \
# 0  [{'id': -1445845615, 'url': 'http://p0.meituan...     True    25434
# 1  [{'id': -1429563625, 'url': 'http://p0.meituan...    False     7293
#
#    replyCnt    reviewId  star     userId  userLevel  userName  \
# 0         0  1674208634    40  291754497          1    q哈哈哈qq
# 1         0  1693519286    40  829297130          2  love勇往直前
#
#                                              userUrl  zanCnt
# 0  https://img.meituan.net/avatar/92de6ba9a330efe...       2
# 1  https://img.meituan.net/avatar/095e2339acd2e50...       0

# %%
df['avgPrice'].value_counts()
# 同一家店的均价应该为同一个数值，所以这列数据没多大的意义
# Out:
# 73    17400
# Name: avgPrice, dtype: int64

# %%
df['anonymous'].value_counts()
# 匿名评价与实名评价的比例大致在5:1左右
# Out:
# False    14402
# True      2998
# Name: anonymous, dtype: int64

# %%
def convertTime(x):
    y=time.localtime(x/1000)
    z=time.strftime("%Y-%m-%d %H:%M:%S",y)
    return z
df["commentTime"]=df["commentTime"].apply(convertTime)
df["commentTime"].head()
# Out:
# 0    2018-05-09 22:21:48
# 1    2018-06-01 19:41:31
# 2    2018-04-04 11:52:23
# 3    2018-05-01 17:12:22
# 4    2018-05-17 16:48:04
# Name: commentTime, dtype: object

# %%
# 在excel可以用筛选器直接看到这列中的数据含有缺失值，或者在拿到数据的时候，使用df.info() 查看每列的数据信息情况
df['dealEndtime'].isna().value_counts()
# 这列数据中含有177个缺失值，其余完整
# Out:
# False    17223
# True       177
# Name: dealEndtime, dtype: int64

# %%
df['commentTime']=pd.to_datetime(df['commentTime'])
df1 = df.set_index('commentTime')
df1.resample('D').size().sort_values(ascending=False).head(100)
df2=df1.resample('M').size().to_period()
df2=df2.reset_index()
# df2.columns
# from pyecharts import  Bar
bar =Bar("按月统计",width=1000,height=400)
bar.add("按月统计",df2['commentTime'],df2[0],is_label_show=True, is_datazoom_show=True,is_toolbox_show=True,is_more_utils=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="64f1b3c3bf0d48d9b18ad884c5cc8744" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_64f1b3c3bf0d48d9b18ad884c5cc8744 = echarts.init(document.getElementById('64f1b3c3bf0d48d9b18ad884c5cc8744'), 'light', {renderer: 'canvas'});
#
# var option_64f1b3c3bf0d48d9b18ad884c5cc8744 = {
#     "title": [
#         {
#             "text": "\u6309\u6708\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 6402351,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6309\u6708\u7edf\u8ba1",
#             "data": [
#                 7.0,
#                 4.0,
#                 53.0,
#                 359.0,
#                 2466.0,
#                 4169.0,
#                 2759.0,
#                 2490.0,
#                 2754.0,
#                 2199.0,
#                 140.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6402351
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6309\u6708\u7edf\u8ba1"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "2017-08",
#                 "2017-09",
#                 "2017-10",
#                 "2017-11",
#                 "2017-12",
#                 "2018-01",
#                 "2018-02",
#                 "2018-03",
#                 "2018-04",
#                 "2018-05",
#                 "2018-06"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal"
#         }
#     ]
# };
# myChart_64f1b3c3bf0d48d9b18ad884c5cc8744.setOption(option_64f1b3c3bf0d48d9b18ad884c5cc8744);
#
#     });
# </script>

# %%
df['commentTime']=pd.to_datetime(df['commentTime'])
df['hour'] = df['commentTime'].dt.hour
df2= df.groupby(['hour']).size()
df2
from pyecharts import  Bar
bar =Bar("按时统计",width=1000,height=400)
bar.add("按时统计",['{} h'.format(i) for i in df2.index],df2.values,is_label_show=True, is_datazoom_show=True,is_toolbox_show=True,is_more_utils=True,is_random=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f4f62b9515f442e89b6b765a818eb307" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f4f62b9515f442e89b6b765a818eb307 = echarts.init(document.getElementById('f4f62b9515f442e89b6b765a818eb307'), 'light', {renderer: 'canvas'});
#
# var option_f4f62b9515f442e89b6b765a818eb307 = {
#     "title": [
#         {
#             "text": "\u6309\u65f6\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 7220158,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6309\u65f6\u7edf\u8ba1",
#             "data": [
#                 419.0,
#                 154.0,
#                 8.0,
#                 40.0,
#                 20.0,
#                 15.0,
#                 49.0,
#                 107.0,
#                 455.0,
#                 665.0,
#                 1068.0,
#                 1471.0,
#                 1176.0,
#                 1275.0,
#                 1046.0,
#                 929.0,
#                 972.0,
#                 1093.0,
#                 1331.0,
#                 1560.0,
#                 1225.0,
#                 979.0,
#                 694.0,
#                 649.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7220158
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6309\u65f6\u7edf\u8ba1"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "0 h",
#                 "1 h",
#                 "2 h",
#                 "3 h",
#                 "4 h",
#                 "5 h",
#                 "6 h",
#                 "7 h",
#                 "8 h",
#                 "9 h",
#                 "10 h",
#                 "11 h",
#                 "12 h",
#                 "13 h",
#                 "14 h",
#                 "15 h",
#                 "16 h",
#                 "17 h",
#                 "18 h",
#                 "19 h",
#                 "20 h",
#                 "21 h",
#                 "22 h",
#                 "23 h"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#bda29a",
#         "#ef5b9c",
#         "#f47920",
#         "#444693",
#         "#749f83",
#         "#6d8346",
#         "#f6f5ec",
#         "#905a3d",
#         "#c23531",
#         "#f05b72",
#         "#c4ccd3",
#         "#1d953f",
#         "#ac6767",
#         "#6e7074",
#         "#2a5caa",
#         "#6950a1",
#         "#61a0a8",
#         "#726930",
#         "#fab27b",
#         "#d48265",
#         "#ca8622",
#         "#918597",
#         "#546570",
#         "#b2d235",
#         "#2f4554"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal"
#         }
#     ]
# };
# myChart_f4f62b9515f442e89b6b765a818eb307.setOption(option_f4f62b9515f442e89b6b765a818eb307);
#
#     });
# </script>

# %%
df['commentTime']=pd.to_datetime(df['commentTime'])
df['day'] = df['commentTime'].dt.day
df2= df.groupby(['day']).size()
df2
from pyecharts import  Bar
bar =Bar("按天统计",width=1000,height=400)
bar.add("按天统计",['{} 日'.format(i) for i in df2.index],df2.values,is_label_show=True, is_datazoom_show=True,is_toolbox_show=True,is_more_utils=True,is_random=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="732f4d7fd79c46989fb4329e905232a0" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_732f4d7fd79c46989fb4329e905232a0 = echarts.init(document.getElementById('732f4d7fd79c46989fb4329e905232a0'), 'light', {renderer: 'canvas'});
#
# var option_732f4d7fd79c46989fb4329e905232a0 = {
#     "title": [
#         {
#             "text": "\u6309\u5929\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 3408803,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6309\u5929\u7edf\u8ba1",
#             "data": [
#                 592.0,
#                 706.0,
#                 667.0,
#                 657.0,
#                 385.0,
#                 614.0,
#                 695.0,
#                 717.0,
#                 426.0,
#                 607.0,
#                 339.0,
#                 725.0,
#                 737.0,
#                 526.0,
#                 434.0,
#                 580.0,
#                 447.0,
#                 572.0,
#                 643.0,
#                 480.0,
#                 476.0,
#                 289.0,
#                 529.0,
#                 640.0,
#                 503.0,
#                 487.0,
#                 628.0,
#                 672.0,
#                 448.0,
#                 553.0,
#                 626.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3408803
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6309\u5929\u7edf\u8ba1"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "1 \u65e5",
#                 "2 \u65e5",
#                 "3 \u65e5",
#                 "4 \u65e5",
#                 "5 \u65e5",
#                 "6 \u65e5",
#                 "7 \u65e5",
#                 "8 \u65e5",
#                 "9 \u65e5",
#                 "10 \u65e5",
#                 "11 \u65e5",
#                 "12 \u65e5",
#                 "13 \u65e5",
#                 "14 \u65e5",
#                 "15 \u65e5",
#                 "16 \u65e5",
#                 "17 \u65e5",
#                 "18 \u65e5",
#                 "19 \u65e5",
#                 "20 \u65e5",
#                 "21 \u65e5",
#                 "22 \u65e5",
#                 "23 \u65e5",
#                 "24 \u65e5",
#                 "25 \u65e5",
#                 "26 \u65e5",
#                 "27 \u65e5",
#                 "28 \u65e5",
#                 "29 \u65e5",
#                 "30 \u65e5",
#                 "31 \u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#546570",
#         "#d48265",
#         "#726930",
#         "#6e7074",
#         "#6950a1",
#         "#c4ccd3",
#         "#bda29a",
#         "#905a3d",
#         "#b2d235",
#         "#2a5caa",
#         "#1d953f",
#         "#f6f5ec",
#         "#f47920",
#         "#fab27b",
#         "#c23531",
#         "#ac6767",
#         "#6d8346",
#         "#444693",
#         "#918597",
#         "#ca8622",
#         "#f05b72",
#         "#2f4554",
#         "#61a0a8",
#         "#749f83",
#         "#ef5b9c"
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal"
#         }
#     ]
# };
# myChart_732f4d7fd79c46989fb4329e905232a0.setOption(option_732f4d7fd79c46989fb4329e905232a0);
#
#     });
# </script>

# %%
df['commentTime']=pd.to_datetime(df['commentTime'])
df['weekday'] = df['commentTime'].dt.weekday
df2= df.groupby(['weekday']).size()
#  周末吃外卖的还是教平时多了一些
from pyecharts import  Bar
bar =Bar("按周统计",width=750,height=400)
weekday=["一","二","三","四","五","六","日"]
bar.add("按周统计",['周{}'.format(i) for i in weekday],df2.values,is_label_show=True, is_datazoom_show=False,is_toolbox_show=True,is_more_utils=True,is_random=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="dcceaad983f54d5cab599efc16e9b7af" style="width:750px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_dcceaad983f54d5cab599efc16e9b7af = echarts.init(document.getElementById('dcceaad983f54d5cab599efc16e9b7af'), 'light', {renderer: 'canvas'});
#
# var option_dcceaad983f54d5cab599efc16e9b7af = {
#     "title": [
#         {
#             "text": "\u6309\u5468\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 1124305,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6309\u5468\u7edf\u8ba1",
#             "data": [
#                 2420.0,
#                 2294.0,
#                 2276.0,
#                 2314.0,
#                 2316.0,
#                 2881.0,
#                 2899.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1124305
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6309\u5468\u7edf\u8ba1"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#2f4554",
#         "#1d953f",
#         "#ac6767",
#         "#bda29a",
#         "#61a0a8",
#         "#f05b72",
#         "#918597",
#         "#6950a1",
#         "#6d8346",
#         "#c23531",
#         "#726930",
#         "#c4ccd3",
#         "#749f83",
#         "#546570",
#         "#905a3d",
#         "#444693",
#         "#ef5b9c",
#         "#ca8622",
#         "#d48265",
#         "#6e7074",
#         "#f47920",
#         "#fab27b",
#         "#2a5caa",
#         "#b2d235",
#         "#f6f5ec"
#     ]
# };
# myChart_dcceaad983f54d5cab599efc16e9b7af.setOption(option_dcceaad983f54d5cab599efc16e9b7af);
#
#     });
# </script>

# %%
# 处理数据前需要先处理缺失值
# 订单结束时间清洗
df['dealEndtime'].fillna(method='ffill').apply(lambda x:time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(x))).head()
# Out:
# 0    2018-06-30 14:00:00
# 1    2018-06-30 14:00:00
# 2    2018-06-30 14:00:00
# 3    2018-06-30 14:00:00
# 4    2018-06-30 14:00:00
# Name: dealEndtime, dtype: object

# %%
df_menu=df['menu'].dropna().astype('category').value_counts()
df_menu
# Out:
# 2人午晚餐                       7640
# 单人午晚餐                       3920
# 学生专享午晚自助                    2638
# 4人午/晚自助                     1581
# 单人下午自助烤肉                     639
# 6人午/晚自助                      507
# 周一至周五自助烤肉/周六日及节假日自助烤肉2选1     209
# 单人午/晚自助                       67
# 周一至周五自助烤肉，免费WiFi              22
# Name: menu, dtype: int64

# %%
from pyecharts import  Bar
bar =Bar("订单分布",width=1100,height=500)
menu_short=['2人午晚餐','单人午晚餐',"学生专享自助","四人自助","6人自助",'单人自助烤肉',"自助烤肉2选1","单人自助","自助wifi"]
bar.add("订单分布",menu_short,df_menu.values,is_label_show=True, is_datazoom_show=False,is_toolbox_show=True,is_more_utils=True,xaxis_rotate=10)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0af215debe224eabb6eb3a312b1fa308" style="width:1100px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0af215debe224eabb6eb3a312b1fa308 = echarts.init(document.getElementById('0af215debe224eabb6eb3a312b1fa308'), 'light', {renderer: 'canvas'});
#
# var option_0af215debe224eabb6eb3a312b1fa308 = {
#     "title": [
#         {
#             "text": "\u8ba2\u5355\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa"
#                 }
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 }
#             }
#         }
#     },
#     "series_id": 2775275,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8ba2\u5355\u5206\u5e03",
#             "data": [
#                 7640.0,
#                 3920.0,
#                 2638.0,
#                 1581.0,
#                 639.0,
#                 507.0,
#                 209.0,
#                 67.0,
#                 22.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2775275
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8ba2\u5355\u5206\u5e03"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 10,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "2\u4eba\u5348\u665a\u9910",
#                 "\u5355\u4eba\u5348\u665a\u9910",
#                 "\u5b66\u751f\u4e13\u4eab\u81ea\u52a9",
#                 "\u56db\u4eba\u81ea\u52a9",
#                 "6\u4eba\u81ea\u52a9",
#                 "\u5355\u4eba\u81ea\u52a9\u70e4\u8089",
#                 "\u81ea\u52a9\u70e4\u80892\u90091",
#                 "\u5355\u4eba\u81ea\u52a9",
#                 "\u81ea\u52a9wifi"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0af215debe224eabb6eb3a312b1fa308.setOption(option_0af215debe224eabb6eb3a312b1fa308);
#
#     });
# </script>

# %%
df['readCnt'].corr(df['star'])
# 评论阅读书与客户评价分数高低的相关性
# Out:
# 0.059092932032050204

# %%
df_most=df[(df["menu"]=="2人午晚餐")]['star'].value_counts().reindex(range(10,60,10))
df_most
# Out:
# 10     329
# 20     533
# 30    2002
# 40    2704
# 50    2072
# Name: star, dtype: int64

# %%
from pyecharts import Line
line =Line("最受欢迎套餐评分分布",width=800,height=400,)
line.add("最受欢迎套餐评分分布",[str(i) for i in range(10,60,10)],df_most.values,is_smooth=True,is_label_show=True)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7196fe9365694904a9bb0322fe9fae30" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7196fe9365694904a9bb0322fe9fae30 = echarts.init(document.getElementById('7196fe9365694904a9bb0322fe9fae30'), 'light', {renderer: 'canvas'});
#
# var option_7196fe9365694904a9bb0322fe9fae30 = {
#     "title": [
#         {
#             "text": "\u6700\u53d7\u6b22\u8fce\u5957\u9910\u8bc4\u5206\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3638262,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6700\u53d7\u6b22\u8fce\u5957\u9910\u8bc4\u5206\u5206\u5e03",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": true,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "10",
#                     329.0
#                 ],
#                 [
#                     "20",
#                     533.0
#                 ],
#                 [
#                     "30",
#                     2002.0
#                 ],
#                 [
#                     "40",
#                     2704.0
#                 ],
#                 [
#                     "50",
#                     2072.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 3638262
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6700\u53d7\u6b22\u8fce\u5957\u9910\u8bc4\u5206\u5206\u5e03"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "10",
#                 "20",
#                 "30",
#                 "40",
#                 "50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_7196fe9365694904a9bb0322fe9fae30.setOption(option_7196fe9365694904a9bb0322fe9fae30);
#
#     });
# </script>

# %%
df[(df["menu"]=="单人午晚餐")]['star'].value_counts()
# Out:
# 30    1215
# 40    1208
# 50    1093
# 20     298
# 10     106
# Name: star, dtype: int64

# %%
# 学生专享午晚自助 
df[(df["menu"]=="学生专享午晚自助")]['star'].value_counts()
# Out:
# 40    954
# 50    863
# 30    529
# 20    191
# 10    101
# Name: star, dtype: int64

# %%
df[(df["menu"]=="4人午/晚自助")]['star'].value_counts()
# Out:
# 50    536
# 30    432
# 40    414
# 10    131
# 20     68
# Name: star, dtype: int64

# %%
df[(df["menu"]=="单人下午自助烤肉")]['star'].value_counts()
# Out:
# 30    208
# 50    169
# 40    144
# 10     98
# 20     20
# Name: star, dtype: int64

# %%
df[(df["menu"]=="6人午/晚自助")]['star'].value_counts()
# Out:
# 50    245
# 40    142
# 30    112
# 10      8
# Name: star, dtype: int64

# %%
#周一至周五自助烤肉/周六日及节假日自助烤肉2选1
df[(df["menu"]=="周一至周五自助烤肉/周六日及节假日自助烤肉2选1")]['star'].value_counts()
# Out:
# 50    87
# 40    66
# 30    46
# 20    10
# Name: star, dtype: int64

# %%
df[(df["menu"]=="单人午/晚自助")]['star'].value_counts()
# Out:
# 50    30
# 40    27
# 30    10
# Name: star, dtype: int64

# %%
df[(df["menu"]=="周一至周五自助烤肉，免费WiFi")]['star'].value_counts().reindex(range(10,51,10)).fillna(0)
# Out:
# 10     0.0
# 20     0.0
# 30     0.0
# 40     0.0
# 50    22.0
# Name: star, dtype: float64

# %%
# df.groupby(['menu','star']).size().to_excel("all_menu_star.xls")
df.groupby(['menu','star']).size()
# Out:
# menu                      star
# 2人午晚餐                     10       329
#                           20       533
#                           30      2002
#                           40      2704
#                           50      2072
# 4人午/晚自助                   10       131
#                           20        68
#                           30       432
#                           40       414
#                           50       536
# 6人午/晚自助                   10         8
#                           30       112
#                           40       142
#                           50       245
# 单人下午自助烤肉                  10        98
#                           20        20
#                           30       208
#                           40       144
#                           50       169
# 单人午/晚自助                   30        10
#                           40        27
#                           50        30
# 单人午晚餐                     10       106
#                           20       298
#                           30      1215
#                           40      1208
#                           50      1093
# 周一至周五自助烤肉/周六日及节假日自助烤肉2选1  20        10
#                           30        46
#                           40        66
#                           50        87
# 周一至周五自助烤肉，免费WiFi          50        22
# 学生专享午晚自助                  10       101
#                           20       191
#                           30       529
#                           40       954
#                           50       863
# dtype: int64

# %%
df.groupby(['star','menu',]).size()
# Out:
# star  menu
# 10    2人午晚餐                        329
#       4人午/晚自助                      131
#       6人午/晚自助                        8
#       单人下午自助烤肉                      98
#       单人午晚餐                        106
#       学生专享午晚自助                     101
# 20    2人午晚餐                        533
#       4人午/晚自助                       68
#       单人下午自助烤肉                      20
#       单人午晚餐                        298
#       周一至周五自助烤肉/周六日及节假日自助烤肉2选1      10
#       学生专享午晚自助                     191
# 30    2人午晚餐                       2002
#       4人午/晚自助                      432
#       6人午/晚自助                      112
#       单人下午自助烤肉                     208
#       单人午/晚自助                       10
#       单人午晚餐                       1215
#       周一至周五自助烤肉/周六日及节假日自助烤肉2选1      46
#       学生专享午晚自助                     529
# 40    2人午晚餐                       2704
#       4人午/晚自助                      414
#       6人午/晚自助                      142
#       单人下午自助烤肉                     144
#       单人午/晚自助                       27
#       单人午晚餐                       1208
#       周一至周五自助烤肉/周六日及节假日自助烤肉2选1      66
#       学生专享午晚自助                     954
# 50    2人午晚餐                       2072
#       4人午/晚自助                      536
#       6人午/晚自助                      245
#       单人下午自助烤肉                     169
#       单人午/晚自助                       30
#       单人午晚餐                       1093
#       周一至周五自助烤肉/周六日及节假日自助烤肉2选1      87
#       周一至周五自助烤肉，免费WiFi              22
#       学生专享午晚自助                     863
# dtype: int64

# %%
df_50=df.groupby(['star','menu',]).size()[50]
df_50
# Out:
# menu
# 2人午晚餐                       2072
# 4人午/晚自助                      536
# 6人午/晚自助                      245
# 单人下午自助烤肉                     169
# 单人午/晚自助                       30
# 单人午晚餐                       1093
# 周一至周五自助烤肉/周六日及节假日自助烤肉2选1      87
# 周一至周五自助烤肉，免费WiFi              22
# 学生专享午晚自助                     863
# dtype: int64

# %%
from pyecharts import Bar
bar= Bar("评分最高的套餐分布",width=800,height=400,)
bar.add("评分最高的套餐分布",menu_short,df_50.values,is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0e3d0d2b8d10441599acdfc4c1692b6c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0e3d0d2b8d10441599acdfc4c1692b6c = echarts.init(document.getElementById('0e3d0d2b8d10441599acdfc4c1692b6c'), 'light', {renderer: 'canvas'});
#
# var option_0e3d0d2b8d10441599acdfc4c1692b6c = {
#     "title": [
#         {
#             "text": "\u8bc4\u5206\u6700\u9ad8\u7684\u5957\u9910\u5206\u5e03",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8070797,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8bc4\u5206\u6700\u9ad8\u7684\u5957\u9910\u5206\u5e03",
#             "data": [
#                 2072.0,
#                 536.0,
#                 245.0,
#                 169.0,
#                 30.0,
#                 1093.0,
#                 87.0,
#                 22.0,
#                 863.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8070797
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8bc4\u5206\u6700\u9ad8\u7684\u5957\u9910\u5206\u5e03"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "2\u4eba\u5348\u665a\u9910",
#                 "\u5355\u4eba\u5348\u665a\u9910",
#                 "\u5b66\u751f\u4e13\u4eab\u81ea\u52a9",
#                 "\u56db\u4eba\u81ea\u52a9",
#                 "6\u4eba\u81ea\u52a9",
#                 "\u5355\u4eba\u81ea\u52a9\u70e4\u8089",
#                 "\u81ea\u52a9\u70e4\u80892\u90091",
#                 "\u5355\u4eba\u81ea\u52a9",
#                 "\u81ea\u52a9wifi"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0e3d0d2b8d10441599acdfc4c1692b6c.setOption(option_0e3d0d2b8d10441599acdfc4c1692b6c);
#
#     });
# </script>

# %%
# userId
# 这家店铺有好多回头客，万万没想到
df[df['userId']!=0]['userId'].value_counts().head(40)
# Out:
# 266045270     64
# 152775497     60
# 80372612      60
# 129840082     60
# 336387962     60
# 34216474      60
# 617772217     60
# 82682689      54
# 287219504     49
# 884729389     45
# 868838851     40
# 409054441     40
# 86939815      40
# 776086712     40
# 48597225      40
# 111808598     40
# 240199490     40
# 83068123      40
# 298504911     40
# 1042639014    40
# 912472277     40
# 98198819      40
# 1494880345    40
# 152930400     40
# 139581136     40
# 404183587     40
# 714781743     40
# 292809386     40
# 18111538      40
# 1097689674    40
# 300905323     40
# 232697160     40
# 141718492     40
# 879430090     40
# 696143486     40
# 13257519      40
# 983797146     40
# 911947863     40
# 993057629     40
# 494215297     40
# Name: userId, dtype: int64

# %%
df[df['userName']!="匿名用户"]['userName'].value_counts().head(40)
# Out:
# xuruiss1026     64
# vTF610712604    60
# jIx325233926    60
# 始于初见的你          60
# 么么哒我是你聪叔        60
# siisgood        60
# 黑发飘呀飘           60
# yumengkou       54
# Daaaav          49
# 梁子7543          45
# TBKLZJ          40
# Mvo148723747    40
# bQl271583480    40
# kingd123        40
# 榴莲馅月饼           40
# Nqr695642404    40
# hiP499857883    40
# oMz861346972    40
# EqI798548999    40
# leeman666888    40
# ihW9198648      40
# 18669978087     40
# 迅行天下            40
# onr243685128    40
# yue国光123        40
# 滨海之恋33          40
# 魔方每团            40
# oUI806055883    40
# 张齐齐123          40
# 小匴盤             40
# VPA342570392    40
# FQe845913598    40
# ree177064067    40
# liE32679330     40
# 西山仙踪            40
# 清晨cxh98         40
# andyliu_1983    40
# SzX539077433    40
# Mqg827794346    40
# qDK538313823    40
# Name: userName, dtype: int64

# %%
df.groupby(['star','userLevel',]).size()
# Out:
# star  userLevel
# 10    0             187
#       1             139
#       2             164
#       3             193
#       4              80
#       5              10
# 20    0             223
#       1              88
#       2             304
#       3             294
#       4             207
#       5              21
# 30    0            1147
#       1             405
#       2            1057
#       3            1230
#       4             570
#       5             165
#       6              20
# 40    0             870
#       1             432
#       2            1360
#       3            1751
#       4            1026
#       5             261
#       6              25
# 50    0             698
#       1             386
#       2            1167
#       3            1670
#       4             802
#       5             318
#       6             130
# dtype: int64

# %%
df_level_star = df.groupby(['userLevel','star']).size()
attr = np.arange(10,60,10)

from pyecharts import Bar
bar = Bar("用户等级与评分",title_pos="center")
df_0 = df_level_star[0].values
df_1 = df_level_star[1].values
df_2 = df_level_star[2].values
df_3 = df_level_star[3].values
df_4 = df_level_star[4].values
df_5 = df_level_star[5].values
# df_6 = df_level_star[6].values
df_6 = df_level_star[6].reindex(attr).fillna(0).values

bar.add("level 0",attr,df_0,is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 1",attr,df_1,is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 2",attr,df_2,is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 3",attr,df_3,mark_line=["average"],mark_point=['max','min'],is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 4",attr,df_4,is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 5",attr,df_5,is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 6",attr,df_6,is_label_show=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0426438b41214004b281d25e5d872413" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0426438b41214004b281d25e5d872413 = echarts.init(document.getElementById('0426438b41214004b281d25e5d872413'), 'light', {renderer: 'canvas'});
#
# var option_0426438b41214004b281d25e5d872413 = {
#     "title": [
#         {
#             "text": "\u7528\u6237\u7b49\u7ea7\u4e0e\u8bc4\u5206",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7958375,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "level 0",
#             "data": [
#                 187.0,
#                 223.0,
#                 1147.0,
#                 870.0,
#                 698.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7958375
#         },
#         {
#             "type": "bar",
#             "name": "level 1",
#             "data": [
#                 139.0,
#                 88.0,
#                 405.0,
#                 432.0,
#                 386.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7958375
#         },
#         {
#             "type": "bar",
#             "name": "level 2",
#             "data": [
#                 164.0,
#                 304.0,
#                 1057.0,
#                 1360.0,
#                 1167.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7958375
#         },
#         {
#             "type": "bar",
#             "name": "level 3",
#             "data": [
#                 193.0,
#                 294.0,
#                 1230.0,
#                 1751.0,
#                 1670.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 7958375
#         },
#         {
#             "type": "bar",
#             "name": "level 4",
#             "data": [
#                 80.0,
#                 207.0,
#                 570.0,
#                 1026.0,
#                 802.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7958375
#         },
#         {
#             "type": "bar",
#             "name": "level 5",
#             "data": [
#                 10.0,
#                 21.0,
#                 165.0,
#                 261.0,
#                 318.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7958375
#         },
#         {
#             "type": "bar",
#             "name": "

# %%
bar = Bar("用户等级与评分",title_pos="center",title_color="red")
attr = np.arange(10,60,10)
df_0 = df_level_star[0].values
df_1 = df_level_star[1].values
df_2 = df_level_star[2].values
df_3 = df_level_star[3].values
df_4 = df_level_star[4].values
df_5 = df_level_star[5].values
# df_6 = df_level_star[6].values
df_6 = df_level_star[6].reindex(attr).fillna(0).values
bar.add("level 0",attr,df_0,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 1",attr,df_1,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 2",attr,df_2,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 3",attr,df_3,is_stack=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 4",attr,df_4,is_stack=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 5",attr,df_5,is_stack=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar.add("level 6",attr,df_6,is_stack=True,legend_pos='right',legend_orient='vertical',label_text_size=12)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="da4201e73dd44f229e896a9b0978e04b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_da4201e73dd44f229e896a9b0978e04b = echarts.init(document.getElementById('da4201e73dd44f229e896a9b0978e04b'), 'light', {renderer: 'canvas'});
#
# var option_da4201e73dd44f229e896a9b0978e04b = {
#     "title": [
#         {
#             "text": "\u7528\u6237\u7b49\u7ea7\u4e0e\u8bc4\u5206",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "color": "red",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 938326,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "level 0",
#             "data": [
#                 187.0,
#                 223.0,
#                 1147.0,
#                 870.0,
#                 698.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         },
#         {
#             "type": "bar",
#             "name": "level 1",
#             "data": [
#                 139.0,
#                 88.0,
#                 405.0,
#                 432.0,
#                 386.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         },
#         {
#             "type": "bar",
#             "name": "level 2",
#             "data": [
#                 164.0,
#                 304.0,
#                 1057.0,
#                 1360.0,
#                 1167.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         },
#         {
#             "type": "bar",
#             "name": "level 3",
#             "data": [
#                 193.0,
#                 294.0,
#                 1230.0,
#                 1751.0,
#                 1670.0
#             ],
#             "stack": "stack_938326",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         },
#         {
#             "type": "bar",
#             "name": "level 4",
#             "data": [
#                 80.0,
#                 207.0,
#                 570.0,
#                 1026.0,
#                 802.0
#             ],
#             "stack": "stack_938326",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         },
#         {
#             "type": "bar",
#             "name": "level 5",
#             "data": [
#                 10.0,
#                 21.0,
#                 165.0,
#                 261.0,
#                 318.0
#             ],
#             "stack": "stack_938326",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         },
#         {
#             "type": "bar",
#             "name": "level 6",
#             "data": [
#                 0.0,
#                 0.0,
#                 20.0,
#                 25.0,
#                 130.0
#             ],
#             "stack": "stack_938326",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 938326
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "level 0",
#                 "level 1",
#                 "level 2",
#                 "level 3",

# %%
df['star'].corr(df['userLevel'])
# Out:
# 0.14389808871897797

# %%
df_zan=df['zanCnt'].value_counts()
from pyecharts import Bar
bar=Bar("点赞统计")
bar.add("点赞分布",df_zan.index[1:],df_zan.values[1:],is_label_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1dc284933220432195fac8361e12e4f2" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1dc284933220432195fac8361e12e4f2 = echarts.init(document.getElementById('1dc284933220432195fac8361e12e4f2'), 'light', {renderer: 'canvas'});
#
# var option_1dc284933220432195fac8361e12e4f2 = {
#     "title": [
#         {
#             "text": "\u70b9\u8d5e\u7edf\u8ba1",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 5182110,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u70b9\u8d5e\u5206\u5e03",
#             "data": [
#                 652.0,
#                 143.0,
#                 119.0,
#                 20.0,
#                 20.0,
#                 20.0,
#                 4.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5182110
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u70b9\u8d5e\u5206\u5e03"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 1.0,
#                 2.0,
#                 3.0,
#                 8.0,
#                 6.0,
#                 4.0,
#                 5.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_1dc284933220432195fac8361e12e4f2.setOption(option_1dc284933220432195fac8361e12e4f2);
#
#     });
# </script>

# %%
df.describe()
# Out:
#        avgPrice   dealEndtime           did       readCnt      replyCnt  \
# count   17400.0  1.722300e+04  1.740000e+04  17400.000000  17400.000000
# mean       73.0  1.529633e+09  4.376319e+07   1622.936149      0.032759
# std         0.0  5.730086e+06  5.749815e+06   4981.816447      0.260349
# min        73.0  1.483078e+09  1.330754e+06     20.000000      0.000000
# 25%        73.0  1.530338e+09  4.432824e+07    162.000000      0.000000
# 50%        73.0  1.530338e+09  4.432824e+07    304.000000      0.000000
# 75%        73.0  1.530338e+09  4.432853e+07    751.000000      0.000000
# max        73.0  1.530338e+09  4.597465e+07  77837.000000      4.000000
#
#            reviewId          star        userId     userLevel        zanCnt  \
# count  1.740000e+04  17400.000000  1.740000e+04  17400.000000  17400.000000
# mean   1.443980e+09     37.691954  3.224900e+08      2.335230      0.096264
# std    2.208396e+08     10.813002  3.914649e+08      1.470979      0.511591
# min    1.093178e+09     10.000000  0.000000e+00      0.000000      0.000000
# 25%    1.197515e+09     30.000000  4.527015e+07      1.000000      0.000000
# 50%    1.606347e+09     40.000000  1.527755e+08      3.000000      0.000000
# 75%    1.646467e+09     50.000000  4.859086e+08      3.000000      0.000000
# max    1.698204e+09     50.000000  1.771740e+09      6.000000      8.000000
#
#                hour           day       weekday
# count  17400.000000  17400.000000  17400.000000
# mean      14.955460     15.603506      3.152356
# std        5.046872      9.131639      2.044944
# min        0.000000      1.000000      0.000000
# 25%       11.000000      8.000000      1.000000
# 50%       15.000000     15.000000      3.000000
# 75%       19.000000     24.000000      5.000000
# max       23.000000     31.000000      6.000000

# %%
df['userLevel'].value_counts().reindex(range(7))
# Out:
# 0    3125
# 1    1450
# 2    4052
# 3    5138
# 4    2685
# 5     775
# 6     175
# Name: userLevel, dtype: int64

# %%
df_level=df['userLevel'].value_counts().reindex(range(7))
from pyecharts import Pie
pie=Pie("用户等级分布",title_pos="center",width=900)
pie.add("levels distribution",["level "+str(i) for i in range(7)],df_level.values,is_random=True,radidus=[30,45],legend_pos='left',rosetype='area',legend_orient='vertical',is_label_show=True,label_text_size=20)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="955bb86dcb524e15b7d9c5004fdd212f" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_955bb86dcb524e15b7d9c5004fdd212f = echarts.init(document.getElementById('955bb86dcb524e15b7d9c5004fdd212f'), 'light', {renderer: 'canvas'});
#
# var option_955bb86dcb524e15b7d9c5004fdd212f = {
#     "title": [
#         {
#             "text": "\u7528\u6237\u7b49\u7ea7\u5206\u5e03",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7723560,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "name": "levels distribution",
#             "data": [
#                 {
#                     "name": "level 0",
#                     "value": 3125.0
#                 },
#                 {
#                     "name": "level 1",
#                     "value": 1450.0
#                 },
#                 {
#                     "name": "level 2",
#                     "value": 4052.0
#                 },
#                 {
#                     "name": "level 3",
#                     "value": 5138.0
#                 },
#                 {
#                     "name": "level 4",
#                     "value": 2685.0
#                 },
#                 {
#                     "name": "level 5",
#                     "value": 775.0
#                 },
#                 {
#                     "name": "level 6",
#                     "value": 175.0
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 20
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 7723560
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "level 0",
#                 "level 1",
#                 "level 2",
#                 "level 3",
#                 "level 4",
#                 "level 5",
#                 "level 6"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#ca8622",
#         "#2a5caa",
#         "#1d953f",
#         "#6950a1",
#         "#749f83",
#         "#bda29a",
#         "#c23531",
#         "#f6f5ec",
#         "#2f4554",
#         "#444693",
#         "#ac6767",
#         "#c4ccd3",
#         "#918597",
#         "#6e7074",
#         "#6d8346",
#         "#61a0a8",
#         "#726930",
#         "#f47920",
#         "#b2d235",
#         "#546570",
#         "#f05b72",
#         "#fab27b",
#         "#ef5b9c",
#         "#905a3d",
#         "#d48265"
#     ]
# };
# myChart_955bb86dcb524e15b7d9c5004fdd212f.setOption(option_955bb86dcb524e15b7d9c5004fdd212f);
#
#     });
# </script>
